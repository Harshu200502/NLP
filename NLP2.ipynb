# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshu200502/NLP/blob/main/NLP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !{sys.executable} -m pip uninstall pandas -y
# Out:
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Successfully uninstalled pandas-2.2.2

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 64.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
import pandas as pd
import csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8dd15320-c8b6-4da7-9e6b-db74402289d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8dd15320-c8b6-4da7-9e6b-db74402289d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output  =pd.read_csv('large_sales_data.csv',sep='\t')

# %%
print(output)
# Out:
#      OrderID,Date,Region,Category,SubCategory,Sales,Profit,Quantity,CustomerType,PaymentMode
# 0     1,2024-01-01 00:00:00,West,Clothing,Mobile,522...
# 1     2,2024-01-01 01:00:00,Central,Books,Table,9098...
# 2     3,2024-01-01 02:00:00,East,Electronics,Laptop,...
# 3     4,2024-01-01 03:00:00,Central,Books,Chair,4756...
# 4     5,2024-01-01 04:00:00,Central,Furniture,Laptop...
# ...                                                 ...
# 2995  2996,2024-05-04 19:00:00,West,Furniture,Novels...
# 2996  2997,2024-05-04 20:00:00,Central,Electronics,L...
# 2997  2998,2024-05-04 21:00:00,East,Electronics,Pant...
# 2998  2999,2024-05-04 22:00:00,South,Clothing,Pants,...
# 2999  3000,2024-05-04 23:00:00,West,Clothing,Chair,6...
#
# [3000 rows x 1 columns]

# %%
with open('large_sales_data.csv','r', encoding='utf-8') as f:
  reader = csv.reader(f)
  for row in reader:
    print(row)
# Out:
# ['OrderID', 'Date', 'Region', 'Category', 'SubCategory', 'Sales', 'Profit', 'Quantity', 'CustomerType', 'PaymentMode']
# ['1', '2024-01-01 00:00:00', 'West', 'Clothing', 'Mobile', '5227', '2636', '33', 'Returning', 'Credit Card']
# ['2', '2024-01-01 01:00:00', 'Central', 'Books', 'Table', '9098', '2948', '23', 'New', 'Wallet']
# ['3', '2024-01-01 02:00:00', 'East', 'Electronics', 'Laptop', '2822', '-460', '13', 'New', 'Cash']
# ['4', '2024-01-01 03:00:00', 'Central', 'Books', 'Chair', '4756', '42', '49', 'VIP', 'UPI']
# ['5', '2024-01-01 04:00:00', 'Central', 'Furniture', 'Laptop', '1425', '-186', '14', 'VIP', 'Cash']
# ['6', '2024-01-01 05:00:00', 'South', 'Food', 'Shirt', '4233', '415', '14', 'VIP', 'Cash']
# ['7', '2024-01-01 06:00:00', 'East', 'Food', 'Mobile', '9451', '1838', '16', 'Returning', 'Cash']
# ['8', '2024-01-01 07:00:00', 'East', 'Furniture', 'Table', '2969', '652', '49', 'Returning', 'Debit Card']
# ...

# %%
import PyPDF2
pdf_file = open('/content/inni.pdf','rb')
reader = PyPDF2.PdfReader(pdf_file)
text = ""
for page in reader.pages:
  text += page.extract_text()
print(text)
pdf_file.close()
# Out:
# Investigating the Impact of Evolving Work Culture
# on Employee Productivity in the Post-Pandemic
# Period
#
# Bharathi Kannamma.V
# Research Associate & Senior People Specialist,
# Sandhata Technologies Pvt Ltd,
# Saveetha School of Engineering, SIMATS ,
# Chennai, Tamil Nadu, India
#  bharathikannamma22594@gmail.com Dr Krithika. M
# Corresponding Author & Assistant Professor,
# Department of Management Studies,
# Saveetha School of Engineering, SIMATS ,
# Chennai, Tamil Nadu, India
#  krithikam.sse@saveetha.com
# Abstract — This study investigates the impact of changing
# work culture on post-pandemic employee productivity through
# a case study of Greater Jakarta. Utilizing multiple regression
# analysis, the research examines how COVID-19-related
# changes in workplace culture, such as increased emphasis on
# health, safety, and flexibility, affect productivity. A survey of
# employees regarding workplace changes revealed preferences
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ef823494-17b1-4771-9a95-a539c488ed07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef823494-17b1-4771-9a95-a539c488ed07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
[+]
