# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshu200502/NLP/blob/main/NLP7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# 1. The Input Text (Oppenheimer Quote)
text_data = [
    """We knew the world would not be the same. A few people laughed, a few people cried.
    Most people were silent. I remembered the line from the Hindu scripture, the Bhagavad Gita;
    Vishnu is trying to persuade the Prince that he should do his duty, and to impress him,
    takes on his multi-armed form and says, 'Now I am become Death, the destroyer of worlds.'
    I suppose we all thought that, one way or another."""
]

# 2. Initialize the CountVectorizer
# stop_words='english' removes common words like 'the', 'is', 'and'
vectorizer = CountVectorizer(stop_words='english')

# 3. Transform the text into the Bag of Words matrix
bow_matrix = vectorizer.fit_transform(text_data)

# 4. Extract Feature Names (The Vocabulary)
vocabulary = vectorizer.get_feature_names_out()

# 5. Convert to a readable DataFrame for your Lab Report
df_bow = pd.DataFrame(bow_matrix.toarray(), columns=vocabulary)

# --- Display Results ---
print("--- Vocabulary List (First 10 words) ---")
print(vocabulary[:10])

print("\n--- Document-Term Matrix (Frequencies) ---")
# Transposing (.T) makes it easier to read when there is only one document
print(df_bow.T.sort_values(by=0, ascending=False))
# Out:
# --- Vocabulary List (First 10 words) ---
# ['armed' 'bhagavad' 'cried' 'death' 'destroyer' 'duty' 'form' 'gita'
#  'hindu' 'impress']
#
# --- Document-Term Matrix (Frequencies) ---
#             0
# people      3
# bhagavad    1
# cried       1
# death       1
# armed       1
# duty        1
# form        1
# gita        1
# hindu       1
# impress     1
# knew        1
# laughed     1
# destroyer   1
# line        1
# multi       1
# persuade    1
# prince      1
# remembered  1
# says        1
# scripture   1
# silent      1
# suppose     1
# takes       1
# thought     1
# trying      1
# vishnu      1
# way         1
# world       1
# worlds      1
